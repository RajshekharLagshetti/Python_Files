# %%
pip install pandas-profiling
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import pandas_profiling
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[10], line 5
#       3 import seaborn as sns
#       4 import os
# ----> 5 import pandas_profiling
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ----> 4 from pandas_profiling.profile_report import ProfileReport
# ...

# %%
pip install pydantic-settings
# Out:
# ...
#
# ...

# %%
df = pd.read_csv("Fitbit_data_scores_excel.csv")

# %%
df.head()
# Out:
#    age  Weight  SO02_level  resting_heart_rate  smoke normal  \
# 0   20     100          99                  68         False
# 1   20      92          99                  55          True
# 2   20      85          90                  76          True
# 3   20      89          87                  61         False
# 4   20      73          89                  75          True
#
#    Stress factor normal  BMI  ECG_normal  average_weekly_steps  \
# 0                  True   19        True                 13762
# 1                  True   19        True                  1099
# 2                  True   20        True                  7885
# 3                  True   19       False                 11309
# 4                  True   27       False                 12889
#
#    sleep_average_weekly  HIIT  Insurance factor
# 0                     5   171              4600
# 1                     5    25              3300
# 2                     9   153              3800
# ...

# %%
df.profile_report()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11552\3787492659.py in ?()
# ----> 1 df.profile_report()
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'profile_report'

# %%
df.describe()
# Out:
#                age       Weight   SO02_level  resting_heart_rate          BMI  \
# count  9999.000000  9999.000000  9999.000000         9999.000000  9999.000000
# mean     34.820482    80.139514    92.173117           64.579058    24.511151
# std       9.007691    11.725943     4.393745            8.863252     3.974419
# min      20.000000    60.000000    85.000000           50.000000    18.000000
# 25%      27.000000    70.000000    88.000000           57.000000    21.000000
# 50%      35.000000    81.000000    92.000000           64.000000    24.000000
# 75%      43.000000    90.000000    96.000000           72.000000    28.000000
# max      50.000000   100.000000    99.000000           80.000000    31.000000
#
#        average_weekly_steps  sleep_average_weekly         HIIT  \
# count           9999.000000           9999.000000  9999.000000
# mean            7194.142914              7.906591   104.952095
# std             4236.802885              2.528113    52.616631
# ...

# %%
df.dtypes
# Out:
# age                     int64
# Weight                  int64
# SO02_level              int64
# resting_heart_rate      int64
# smoke normal             bool
# Stress factor normal     bool
# BMI                     int64
# ECG_normal               bool
# average_weekly_steps    int64
# sleep_average_weekly    int64
# HIIT                    int64
# Insurance factor        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['age', 'Weight', 'SO02_level', 'resting_heart_rate', 'smoke normal',
#        'Stress factor normal', 'BMI', 'ECG_normal', 'average_weekly_steps',
#        'sleep_average_weekly', 'HIIT', 'Insurance factor'],
#       dtype='object')

# %%
df.shape
# Out:
# (9999, 12)

# %%
df['ActivityDate']=pd.date_range('2024-4-01',periods=9999)

# %%
df
# Out:
#       age  Weight  SO02_level  resting_heart_rate  smoke normal  \
# 0      20     100          99                  68         False
# 1      20      92          99                  55          True
# 2      20      85          90                  76          True
# 3      20      89          87                  61         False
# 4      20      73          89                  75          True
# ...   ...     ...         ...                 ...           ...
# 9994   20      86          99                  56          True
# 9995   20      95          87                  71          True
# 9996   20      64          93                  50          True
# 9997   20      69          90                  74          True
# 9998   20      87          89                  58          True
#
#       Stress factor normal  BMI  ECG_normal  average_weekly_steps  \
# 0                     True   19        True                 13762
# ...

# %%
df.dtypes
# Out:
# age                              int64
# Weight                           int64
# SO02_level                       int64
# resting_heart_rate               int64
# smoke normal                      bool
# Stress factor normal              bool
# BMI                              int64
# ECG_normal                        bool
# average_weekly_steps             int64
# sleep_average_weekly             int64
# HIIT                             int64
# Insurance factor                 int64
# ActivityDate            datetime64[ns]
# dtype: object

# %%
 df['day'] = pd.DatetimeIndex(df['ActivityDate']).day

# %%
df
# Out:
#       age  Weight  SO02_level  resting_heart_rate  smoke normal  \
# 0      20     100          99                  68         False
# 1      20      92          99                  55          True
# 2      20      85          90                  76          True
# 3      20      89          87                  61         False
# 4      20      73          89                  75          True
# ...   ...     ...         ...                 ...           ...
# 9994   20      86          99                  56          True
# 9995   20      95          87                  71          True
# 9996   20      64          93                  50          True
# 9997   20      69          90                  74          True
# 9998   20      87          89                  58          True
#
#       Stress factor normal  BMI  ECG_normal  average_weekly_steps  \
# 0                     True   19        True                 13762
# ...

# %%
df.drop('ActivityDate',axis=1)
# Out:
#       age  Weight  SO02_level  resting_heart_rate  smoke normal  \
# 0      20     100          99                  68         False
# 1      20      92          99                  55          True
# 2      20      85          90                  76          True
# 3      20      89          87                  61         False
# 4      20      73          89                  75          True
# ...   ...     ...         ...                 ...           ...
# 9994   20      86          99                  56          True
# 9995   20      95          87                  71          True
# 9996   20      64          93                  50          True
# 9997   20      69          90                  74          True
# 9998   20      87          89                  58          True
#
#       Stress factor normal  BMI  ECG_normal  average_weekly_steps  \
# 0                     True   19        True                 13762
# ...

# %%
df1 = pd.read_csv('fitbit fitness tracker data/mturkfitbit_export_3.12.16-4.11.16/Fitabase Data 3.12.16-4.11.16/dailyActivity_merged.csv')

# %%
df1.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %%
df1['day'] = pd.DatetimeIndex(df1['ActivityDate']).day

# %%
df1['day_name'] = pd.DatetimeIndex(df1['ActivityDate']).day_name()

# %%
df1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='day',y='Calories',data=df1)
# Out:
# <Axes: xlabel='day', ylabel='Calories'>

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x='day_name',y='Calories',data=df1)
# Out:
# <Axes: xlabel='day_name', ylabel='Calories'>

# %%
df1['week'] = pd.DatetimeIndex(df1['ActivityDate']).weekday

# %%
df1
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
sns.scatterplot(x='Calories',y='TotalSteps', data = df1)
# Out:
# <Axes: xlabel='Calories', ylabel='TotalSteps'>
